# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
ts = pd.Series(np.random.randint(0, high = 100, size = 1000), index=pd.date_range("1/1/2000", periods=1000))

# %%
ts = ts.cumsum()
ts.plot();

# %%
my_array = [[0, 12], [1, 15], [2, 10], [3, 5], [4, 15]]

# %%
my_array
# Out:
# [[0, 12], [1, 15], [2, 10], [3, 5], [4, 15]]

# %%
df = pd.DataFrame(my_array, columns =['ID', 'Age'])

# %%
df
# Out:
#    ID  Age
# 0   0   12
# 1   1   15
# 2   2   10
# 3   3    5
# 4   4   15

# %%
df['Age'].plot()

# %%
my_array2 = [[0, 1, 2, 3, 4]]

# %%
plt.figure(figsize=(10, 10))
plt.pie(my_array2[0])
plt.show()
